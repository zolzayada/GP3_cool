# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from time import sleep

# %%
driver = webdriver.Chrome()
driver.get("https://store.steampowered.com/search/?ndl=1")

# %%
def scrolldown(driver, vniz): #крч функция, которая мотает страницу вниз, чтобы больше игр прогрузилось
    for i in range(vniz):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") #JavaScript-код для браузера, который обращается к DOM страницы
        #https://developer.mozilla.org/en-US/docs/Web/API/Window/scrollTo?.com
        #https://developer.mozilla.org/en-US/docs/Web/API/Document/body?.com
        #https://developer.mozilla.org/en-US/docs/Web/API/Element/scrollHeight?.com
        sleep(2)

# %%
scrolldown(driver, 5)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
urls = []

for link in soup.find_all('a'):
    if '/app' in link.get('href') and link.get('href').startswith('https://'):
        urls.append(link.get('href'))

print(len(urls))
# Out:
# 50

# %%
url0 = urls[3]

driver.get(url0)
html = driver.page_source
soup0 = BeautifulSoup(html, 'html.parser')
print(soup0.prettify())
# Out:
# <html class="responsive DesktopUI" lang="ru">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="#171a21" name="theme-color"/>
#   <title>
#    Dota 2 в Steam
#   </title>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://store.fastly.steamstatic.com/public/shared/css/motiva_sans.css?v=YzJgj1FjzW34&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/shared/css/shared_global.css?v=qbbUOQL2SbhT&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/shared/css/buttons.css?v=BZhNEtESfYSJ&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/v6/store.css?v=13CjnPuGjLMj&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/shared/css/user_reviews.css?v=hm9SZwgMOb_k&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/shared/css/store_game_shared.css?v=h3rDvpE1fR8Z&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/v6/game.css?v=bVzlUjYs3pI4&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/shared/css/store_background_shared.css?v=RuX0Jh-U_mAP&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/v6/recommended.css?v=H2Bs71oRS3x2&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/v6/user_reviews_rewards.css?v=nDJVyLGQ1XMI&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/shared/css/apphub.css?v=ZlosKEPyDnlL&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/shared/css/ui-lightness/jquery-ui-1.7.2.custom.css?v=qgq7mHqEwLbE&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/v6/game_mob.css?v=vE7NVQtmyezW&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/shared/css/shared_responsive.css?v=bVAhy8BAW0iP&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#   <script src="https://store.fastly.steamstatic.com/public/shared/javascript/jquery-1.8.3.min.js?v=NXam5zydzNu8&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $J = jQuery.noConflict();
#   </script>
#   <script type="text/javascript">
#    VALVE_PUBLIC_PATH = "https:\/\/store.fastly.steamstatic.com\/public\/";
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/shared/javascript/tooltip.js?v=k5leO7MVvAaV&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/shared/javascript/shared_global.js?v=648ewX3c6IPx&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/shared/javascript/auth_refresh.js?v=w6QbwI-5-j2S&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/javascript/main.js?v=NNEREeb08xjw&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/javascript/dynamicstore.js?v=8HMZJ2vfYeIG&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    Object.seal && [ Object, Array, String, Number ].map( function( builtin ) { Object.seal( builtin.prototype ); } );
#   </script>
#   <script type="text/javascript">
#    document.addEventListener('DOMContentLoaded', function(event) {
# 				$J.data( document, 'x_readytime', new Date().getTime() );
# 				$J.data( document, 'x_oldref', GetNavCookie() );
# 				SetupTooltips( { tooltipCSSClass: 'store_tooltip'  } );
# 		});
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/javascript/gamehighlightplayer.js?v=BD8M_G-UM3Bq&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/shared/javascript/user_reviews.js?v=c_wRsohiHTg7&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/shared/javascript/dselect.js?v=w0CV_PAvw3UA&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/javascript/app_tagging.js?v=xWuswvPdHvh5&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/javascript/game.js?v=WBR9sG45oxt4&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/shared/javascript/flot-0.8/jquery.flot.min.js?v=mSfqk1QKKgiz&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/shared/javascript/flot-0.8/jquery.flot.resize.min.js?v=MeIf0YViALgL&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/shared/javascript/flot-0.8/jquery.flot.time.min.js?v=CIECDYHJjBgN&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/shared/javascript/flot-0.8/jquery.flot.selection.min.js?v=laPWW88ZIIHe&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/shared/javascript/jquery-ui-1.9.2.js?v=Bu2RA9fLXSi-&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <script src="https://store.fastly.steamstatic.com/public/shared/javascript/shared_responsive_adapter.js?v=s6Ss5q8K2tHd&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#   </script>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="Ежедневно миллионы игроков по всему миру сражаются от лица одного из более сотни героев Dota 2, и даже после тысячи часов в ней есть чему научиться. Благодаря регулярным обновлениям игра живёт своей жизнью: геймплей, возможности и герои постоянно преображаются." name="Description"/>
#   <meta content="@steam" name="twitter:site"/>
#   <meta content="Dota 2 в Steam" property="og:title"/>
#   <meta content="Dota 2 в Steam" property="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="105386699540688" property="fb:app_id"/>
#   <meta content="Steam" property="og:site"/>
#   <meta content="https://store.steampowered.com/app/570/Dota_2/" property="og:url"/>
#   <meta content="Ежедневно миллионы игроков по всему миру сражаются от лица одного из более сотни героев Dota 2, и даже после тысячи часов в ней есть чему научиться. Благодаря регулярным обновлениям игра живёт своей жизнью: геймплей, возможности и герои постоянно преображаются." property="og:description"/>
#   <meta content="Ежедневно миллионы игроков по всему миру сражаются от лица одного из более сотни героев Dota 2, и даже после тысячи часов в ней есть чему научиться. Благодаря регулярным обновлениям игра живёт своей жизнью: геймплей, возможности и герои постоянно преображаются." property="twitter:description"/>
#   <link href="https://store.steampowered.com/app/570/Dota_2/" rel="canonical"/>
#   <link href="https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/570/capsule_616x353.jpg?t=1769535998" rel="image_src"/>
#   <meta content="https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/570/capsule_616x353.jpg?t=1769535998" property="og:image"/>
#   <meta content="https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/570/capsule_616x353.jpg?t=1769535998" name="twitter:image"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/applications/store/openindesktopclient.css?contenthash=79b6a827de7e2bdab6c6" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/applications/store/4781.css?contenthash=349e976846ddfbe022a9" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/applications/store/706.css?contenthash=3f674d597883b44f1e5b" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/applications/store/6769.css?contenthash=e45ca73bf2ad95ad2132" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/applications/store/1677.css?contenthash=531665ef5bfb1a49d68c" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/applications/store/chunk~512672cf3.css?contenthash=f70b755ad32b2463ad0e" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/applications/store/chunk~4e1b7930f.css?contenthash=bf7249b8c55a0a00206e" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/applications/store/chunk~16cbe8ea0.css?contenthash=994206a948dcc46477ef" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/applications/store/chunk~b31c80439.css?contenthash=6eaa8ab2b55aa3676989" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/applications/store/chunk~6026e71fe.css?contenthash=5c316ee66c32ec610afe" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/applications/store/apppage.css?contenthash=c1c128d5735e64ac4447" rel="stylesheet" type="text/css"/>
#   <link href="https://store.fastly.steamstatic.com/public/css/applications/store/accessibility.css?contenthash=4e22738de72e9cb6bae3" rel="stylesheet" type="text/css"/>
#  </head>
#  <body class="v6 app game_bg menu_background_overlap application widestore v7menu responsive_page">
#   <div class="responsive_page_frame with_header">
#    <div aria-label="Мобильное меню" class="responsive_page_menu_ctn mainmenu" role="navigation">
#     <div class="responsive_page_menu" id="responsive_page_menu">
#      <div class="mainmenu_contents">
#       <div class="mainmenu_contents_items">
#        <a class="menuitem" href="https://store.steampowered.com/login/?redir=app%2F570%2FDota_2%2F%3Fsnr%3D1_7_7_230_150_1&amp;redir_ssl=1&amp;snr=1_5_9__global-header">
#         Войти
#        </a>
#        <a class="menuitem supernav supernav_active" data-tooltip-content=".submenu_Store" data-tooltip-type="selector" href="https://store.steampowered.com/?snr=1_5_9__global-responsive-menu">
#         Магазин
#        </a>
#        <div class="submenu_Store" data-submenuid="Store" style="display: none;">
#         <a class="submenuitem" href="https://store.steampowered.com/?snr=1_5_9__global-responsive-menu">
#          Главная
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/explore/?snr=1_5_9__global-responsive-menu">
#          Рекомендации
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/my/wishlist/">
#          Список желаемого
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/points/shop/?snr=1_5_9__global-responsive-menu">
#          Предметы за очки
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/news/?snr=1_5_9__global-responsive-menu">
#          Новости
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/stats/?snr=1_5_9__global-responsive-menu">
#          Чарты
#         </a>
#        </div>
#        <a class="menuitem supernav" data-tooltip-content=".submenu_Community" data-tooltip-type="selector" href="https://steamcommunity.com/">
#         Сообщество
#        </a>
#        <div class="submenu_Community" data-submenuid="Community" style="display: none;">
#         <a class="submenuitem" href="https://steamcommunity.com/">
#          Главная
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/discussions/">
#          Обсуждения
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/workshop/">
#          Мастерская
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/market/">
#          Торговая площадка
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/?subsection=broadcasts">
#          Трансляции
#         </a>
#        </div>
#        <a class="menuitem" href="https://store.steampowered.com/about/?snr=1_5_9__global-responsive-menu">
#         Информация
#        </a>
#        <a class="menuitem" href="https://help.steampowered.com/ru/">
#         Поддержка
#        </a>
#        <div class="minor_menu_items">
#         <div class="menuitem change_language_action">
#          Изменить язык
#         </div>
#         <a class="menuitem" href="https://store.steampowered.com/mobile" rel="noreferrer" target="_blank">
#          Скачать мобильное приложение Steam
#         </a>
#         <div class="menuitem" onclick="Responsive_RequestDesktopView();" role="link">
#          Полная версия
#         </div>
#        </div>
#       </div>
#       <div class="mainmenu_footer_spacer">
#       </div>
#       <div class="mainmenu_footer">
#        <div class="mainmenu_footer_logo">
#         <img src="https://store.fastly.steamstatic.com/public/shared/images/responsive/footerLogo_valve_new.png"/>
#        </div>
#        © Valve Corporation. Все права сохранены. Все торговые марки являются собственностью соответствующих владельцев в США и других странах.
#        <span class="mainmenu_valve_links">
#         <a href="https://store.steampowered.com/privacy_agreement/?snr=1_5_9__global-responsive-menu" target="_blank">
#          Политика конфиденциальности
#         </a>
#         |
#         <a href="http://www.valvesoftware.com/legal.htm" target="_blank">
#          Правовая информация
#         </a>
#         |
#         <a href="https://help.steampowered.com/faqs/view/10BB-D27A-6378-4436" target="_blank">
#          Доступность
#         </a>
#         |
#         <a href="https://store.steampowered.com/subscriber_agreement/?snr=1_5_9__global-responsive-menu" target="_blank">
#          Соглашение подписчика Steam
#         </a>
#         |
#         <a href="https://store.steampowered.com/steam_refunds/?snr=1_5_9__global-responsive-menu" target="_blank">
#          Возврат средств
#         </a>
#         |
#         <a href="https://store.steampowered.com/account/cookiepreferences/?snr=1_5_9__global-responsive-menu" target="_blank">
#          Файлы cookie
#         </a>
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="responsive_local_menu_tab">
#    </div>
#    <div class="responsive_page_menu_ctn localmenu">
#     <div class="responsive_page_menu" data-panel='{"onOptionsActionDescription":"\u0424\u0438\u043b\u044c\u0442\u0440\u043e\u0432\u0430\u0442\u044c","onOptionsButton":"Responsive_ToggleLocalMenu()","onCancelButton":"Responsive_ToggleLocalMenu()"}' id="responsive_page_local_menu">
#      <div class="localmenu_content" data-panel='{"maintainY":true,"bFocusRingRoot":true,"flow-children":"column"}'>
#      </div>
#     </div>
#    </div>
#    <div class="responsive_header">
#     <div class="responsive_header_content">
#      <div id="responsive_menu_logo">
#       <img height="100%" src="https://store.fastly.steamstatic.com/public/shared/images/responsive/header_menu_hamburger.png"/>
#      </div>
#      <div class="responsive_header_logo">
#       <a href="https://store.steampowered.com/?snr=1_5_9__global-responsive-menu">
#        <img alt="STEAM" border="0" height="36" src="https://store.fastly.steamstatic.com/public/shared/images/responsive/header_logo.png"/>
#       </a>
#      </div>
#      <div class="responsive_header_react_target" data-featuretarget="store-menu-responsive-search">
#       <div class="responsive_header_react_placeholder">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="responsive_page_content_overlay">
#    </div>
#    <div class="responsive_fixonscroll_ctn nonresponsive_hidden">
#    </div>
#    <div class="responsive_page_content">
#     <div data-panel='{"flow-children":"row"}' id="global_header" role="banner">
#      <div class="content">
#       <div class="logo">
#        <span id="logo_holder">
#         <a aria-label="Ссылка на домашнюю страницу Steam" href="https://store.steampowered.com/?snr=1_5_9__global-header">
#          <img alt="Ссылка на домашнюю страницу Steam" height="44" src="https://store.fastly.steamstatic.com/public/shared/images/header/logo_steam.svg?t=962016" width="176"/>
#         </a>
#        </span>
#       </div>
#       <div aria-label="Глобальное меню" class="supernav_container" role="navigation">
#        <a class="menuitem supernav supernav_active" data-tooltip-content=".submenu_Store" data-tooltip-type="selector" href="https://store.steampowered.com/?snr=1_5_9__global-header">
#         МАГАЗИН
#        </a>
#        <div class="submenu_Store" data-submenuid="Store" style="display: none;">
#         <a class="submenuitem" href="https://store.steampowered.com/?snr=1_5_9__global-header">
#          Главная
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/explore/?snr=1_5_9__global-header">
#          Рекомендации
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/my/wishlist/">
#          Список желаемого
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/points/shop/?snr=1_5_9__global-header">
#          Предметы за очки
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/news/?snr=1_5_9__global-header">
#          Новости
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/stats/?snr=1_5_9__global-header">
#          Чарты
#         </a>
#        </div>
#        <a class="menuitem supernav" data-tooltip-content=".submenu_Community" data-tooltip-type="selector" href="https://steamcommunity.com/">
#         СООБЩЕСТВО
#        </a>
#        <div class="submenu_Community" data-submenuid="Community" style="display: none;">
#         <a class="submenuitem" href="https://steamcommunity.com/">
#          Главная
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/discussions/">
#          Обсуждения
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/workshop/">
#          Мастерская
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/market/">
#          Торговая площадка
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/?subsection=broadcasts">
#          Трансляции
#         </a>
#        </div>
#        <a class="menuitem" href="https://store.steampowered.com/about/?snr=1_5_9__global-header">
#         Информация
#        </a>
#        <a class="menuitem" href="https://help.steampowered.com/ru/">
#         ПОДДЕРЖКА
#        </a>
#       </div>
#       <script type="text/javascript">
#        jQuery(function($) {
# 			$('#global_header .supernav').v_tooltip({'location':'bottom', 'destroyWhenDone': false, 'tooltipClass': 'supernav_content', 'offsetY':-6, 'offsetX': 1, 'horizontalSnap': 4, 'tooltipParent': '#global_header .supernav_container', 'correctForScreenSize': false});
# 		});
#       </script>
#       <div id="global_actions">
#        <div aria-label="Меню аккаунта" id="global_action_menu" role="navigation">
#         <a class="header_installsteam_btn header_installsteam_btn_green" href="https://store.steampowered.com/about/?snr=1_5_9__global-header">
#          <div class="header_installsteam_btn_content">
#           Установить Steam
#          </div>
#         </a>
#         <a class="global_action_link" href="https://store.steampowered.com/login/?redir=app%2F570%2FDota_2%2F%3Fsnr%3D1_7_7_230_150_1&amp;redir_ssl=1&amp;snr=1_5_9__global-header">
#          вход
#         </a>
#         |
#         <span class="pulldown global_action_link" id="language_pulldown" onclick="ShowMenu( this, 'language_dropdown', 'right' );">
#          язык
#         </span>
#         <div class="popup_block_new" id="language_dropdown" style="display: none;">
#          <div class="popup_body popup_menu">
#           <a class="popup_menu_item tight" href="?l=schinese&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'schinese' ); return false;">
#            简体中文 (упрощенный китайский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=tchinese&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'tchinese' ); return false;">
#            繁體中文 (традиционный китайский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=japanese&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'japanese' ); return false;">
#            日本語 (японский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=koreana&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'koreana' ); return false;">
#            한국어 (корейский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=thai&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'thai' ); return false;">
#            ไทย (тайский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=bulgarian&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'bulgarian' ); return false;">
#            Български (болгарский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=czech&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'czech' ); return false;">
#            Čeština (чешский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=danish&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'danish' ); return false;">
#            Dansk (датский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=german&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'german' ); return false;">
#            Deutsch (немецкий)
#           </a>
#           <a class="popup_menu_item tight" href="?l=english&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'english' ); return false;">
#            English (английский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=spanish&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'spanish' ); return false;">
#            Español - España (испанский — Испания)
#           </a>
#           <a class="popup_menu_item tight" href="?l=latam&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'latam' ); return false;">
#            Español - Latinoamérica (испанский — Латинская Америка)
#           </a>
#           <a class="popup_menu_item tight" href="?l=greek&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'greek' ); return false;">
#            Ελληνικά (греческий)
#           </a>
#           <a class="popup_menu_item tight" href="?l=french&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'french' ); return false;">
#            Français (французский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=italian&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'italian' ); return false;">
#            Italiano (итальянский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=indonesian&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'indonesian' ); return false;">
#            Bahasa Indonesia (индонезийский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=hungarian&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'hungarian' ); return false;">
#            Magyar (венгерский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=dutch&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'dutch' ); return false;">
#            Nederlands (нидерландский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=norwegian&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'norwegian' ); return false;">
#            Norsk (норвежский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=polish&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'polish' ); return false;">
#            Polski (польский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=portuguese&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'portuguese' ); return false;">
#            Português (португальский — Португалия)
#           </a>
#           <a class="popup_menu_item tight" href="?l=brazilian&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'brazilian' ); return false;">
#            Português-Brasil (португальский — Бразилия)
#           </a>
#           <a class="popup_menu_item tight" href="?l=romanian&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'romanian' ); return false;">
#            Română (румынский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=finnish&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'finnish' ); return false;">
#            Suomi (финский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=swedish&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'swedish' ); return false;">
#            Svenska (шведский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=turkish&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'turkish' ); return false;">
#            Türkçe (турецкий)
#           </a>
#           <a class="popup_menu_item tight" href="?l=vietnamese&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'vietnamese' ); return false;">
#            Tiếng Việt (вьетнамский)
#           </a>
#           <a class="popup_menu_item tight" href="?l=ukrainian&amp;snr=1_7_7_230_150_1" onclick="ChangeLanguage( 'ukrainian' ); return false;">
#            Українська (украинский)
#           </a>
#           <a class="popup_menu_item tight" href="https://www.valvesoftware.com/en/contact?contact-person=Translation%20Team%20Feedback" target="_blank">
#            Сообщить о проблеме с переводом
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="_2QlYKhF-leHfMXFSiSshZC" data-featuretarget="store-menu-v7">
#      <div class="PlaceholderInner">
#      </div>
#      <div class="_2MzjSFlY9PHeDbUgNhjlOa">
#       <div class="pzuGfMA6MeGlV2I3yY60c _1Zsv2NkXHxE5LTvs92Jqvd">
#        <div class="h2B3SGR_w4RWdrnsRZEcD">
#         <div class="_3FIjYetykQsFYR08l1v7Ls">
#         </div>
#         <div class="_16jZ3HEbtaJTl80pQINN2Y Panel Focusable">
#          <div aria-label="Меню магазина" class="_7FiqKP7fZJGltkwRxPG6s Panel Focusable" role="navigation">
#           <div class="_1u2HkRz_FnAfR5OjfjexgF">
#            <div class="_315CcpqsgdwaAwR3WiSlOq">
#             <div class="_3CtcPWgZYR05CldoJ0Jkrx">
#              <button aria-expanded="false" class="_175B12uOwmeGBNcSaQFe-Z _3wlHWKFbgRAZPFtWEr65YT Focusable" role="button">
#               <div class="vj9hwW9u0MpjH7MVjjNw0">
#                Просмотр
#                <div class="_1-hPfsxjynE3demuqGmqf0">
#                 <div class="_3gaaE-cRfFWJdZcC8XMi0x">
#                 </div>
#                </div>
#               </div>
#               <svg fill="none" role="presentation" viewbox="0 0 12 12" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M5.81026 6.36084L8.50899 3.66211L9.6875 4.84062L5.81026 8.71786L1.93302 4.84062L3.11153 3.66211L5.81026 6.36084Z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </button>
#              <button aria-expanded="false" class="_175B12uOwmeGBNcSaQFe-Z _3wlHWKFbgRAZPFtWEr65YT Focusable" role="button">
#               <div class="vj9hwW9u0MpjH7MVjjNw0">
#                Рекомендации
#                <div class="_1-hPfsxjynE3demuqGmqf0">
#                 <div class="_3gaaE-cRfFWJdZcC8XMi0x">
#                 </div>
#                </div>
#               </div>
#               <svg fill="none" role="presentation" viewbox="0 0 12 12" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M5.81026 6.36084L8.50899 3.66211L9.6875 4.84062L5.81026 8.71786L1.93302 4.84062L3.11153 3.66211L5.81026 6.36084Z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </button>
#              <button aria-expanded="false" class="_175B12uOwmeGBNcSaQFe-Z _3wlHWKFbgRAZPFtWEr65YT Focusable" role="button">
#               <div class="vj9hwW9u0MpjH7MVjjNw0">
#                Категории
#                <div class="_1-hPfsxjynE3demuqGmqf0">
#                 <div class="_3gaaE-cRfFWJdZcC8XMi0x">
#                 </div>
#                </div>
#               </div>
#               <svg fill="none" role="presentation" viewbox="0 0 12 12" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M5.81026 6.36084L8.50899 3.66211L9.6875 4.84062L5.81026 8.71786L1.93302 4.84062L3.11153 3.66211L5.81026 6.36084Z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </button>
#              <button aria-expanded="false" class="_175B12uOwmeGBNcSaQFe-Z _3wlHWKFbgRAZPFtWEr65YT Focusable" role="button">
#               <div class="vj9hwW9u0MpjH7MVjjNw0">
#                Способы игры
#                <div class="_1-hPfsxjynE3demuqGmqf0">
#                 <div class="_3gaaE-cRfFWJdZcC8XMi0x">
#                 </div>
#                </div>
#               </div>
#               <svg fill="none" role="presentation" viewbox="0 0 12 12" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M5.81026 6.36084L8.50899 3.66211L9.6875 4.84062L5.81026 8.71786L1.93302 4.84062L3.11153 3.66211L5.81026 6.36084Z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </button>
#              <button aria-expanded="false" class="_175B12uOwmeGBNcSaQFe-Z _3wlHWKFbgRAZPFtWEr65YT Focusable" role="button">
#               <div class="vj9hwW9u0MpjH7MVjjNw0">
#                Особые разделы
#                <div class="_1-hPfsxjynE3demuqGmqf0">
#                 <div class="_3gaaE-cRfFWJdZcC8XMi0x">
#                 </div>
#                </div>
#               </div>
#               <svg fill="none" role="presentation" viewbox="0 0 12 12" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M5.81026 6.36084L8.50899 3.66211L9.6875 4.84062L5.81026 8.71786L1.93302 4.84062L3.11153 3.66211L5.81026 6.36084Z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </button>
#             </div>
#            </div>
#            <div class="WFyPwmwIjPaI784fImRbi">
#             <form action="https://store.steampowered.com/search" class="_1KU9eASfov1GnFQRbyLIdR" method="GET" role="search">
#              <input name="snr" type="hidden" value="1_12_4__7"/>
#              <div class="_2AD2O_FEWy7izR8sZZjjI6">
#               <input aria-autocomplete="list" aria-expanded="false" autocomplete="off" class="_2tlUAG6WNyYFlk9caIiLj5" name="term" placeholder="Поиск по магазину" role="combobox" type="text" value=""/>
#              </div>
#              <button class="_1Yo-ZsBr-KbVMyAMXEYszd" type="submit">
#               <svg aria-label="Поиск" fill="none" viewbox="0 0 18 18" xmlns="http://www.w3.org/2000/svg">
#                <path d="M13.8296 12.0786C14.8347 10.6321 15.2623 8.86133 15.0284 7.11496C14.7945 5.36859 13.9159 3.77313 12.5656 2.64269C11.2153 1.51224 9.49114 0.928708 7.73254 1.00696C5.97394 1.08522 4.30831 1.8196 3.06357 3.06552C1.81882 4.31144 1.08514 5.97864 1.00696 7.7389C0.928776 9.49916 1.51176 11.2249 2.64114 12.5765C3.77052 13.9281 5.36446 14.8075 7.10919 15.0417C8.85391 15.2758 10.623 14.8477 12.0682 13.8417L15.2185 17L15.3997 16.8187L16.8188 15.3982L17 15.2168L13.8296 12.0786ZM8.04222 12.5824C7.14643 12.5824 6.27075 12.3165 5.52593 11.8183C4.7811 11.3202 4.20058 10.6122 3.85777 9.78376C3.51497 8.95538 3.42528 8.04384 3.60004 7.16443C3.7748 6.28502 4.20616 5.47723 4.83958 4.84321C5.47301 4.20919 6.28004 3.77742 7.15862 3.60249C8.0372 3.42757 8.94787 3.51734 9.77548 3.86047C10.6031 4.2036 11.3104 4.78467 11.8081 5.5302C12.3058 6.27573 12.5714 7.15223 12.5714 8.04887C12.5714 9.25123 12.0943 10.4043 11.2449 11.2545C10.3955 12.1047 9.24344 12.5824 8.04222 12.5824V12.5824Z" fill="currentColor">
#                </path>
#               </svg>
#              </button>
#             </form>
#             <div class="HWDmfh8Td_a8zxJu6tP0h">
#              <div class="SWL3uBHWmdcYwUXE9yD0y" inert="" style="height: 0px; overflow: hidden; transition: height 100ms;">
#               <div class="_2GxMhpm7OC2WWXN_wjgA78" id="searchSuggestions_«r0»">
#                <a class="_2Cp17yynz2h_StEQZcNnqB" href="https://store.steampowered.com/search/?term=&amp;snr=1_7_15__advancedsearch">
#                 <span class="NOctYARrXun3C2m8ZOA3u">
#                  Расширенный поиск
#                 </span>
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="_1wn1lBlAzl3HMRqS1llwie">
#           </div>
#          </div>
#         </div>
#         <div class="_19o1GB7ysfrWKLYpqZ6aXu">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div id="responsive_store_nav_ctn">
#     </div>
#     <div id="responsive_store_nav_overlay" style="display:none">
#      <div id="responsive_store_nav_overlay_ctn">
#      </div>
#      <div id="responsive_store_nav_overlay_bottom">
#      </div>
#     </div>
#     <div id="responsive_store_search_overlay" style="display:none">
#     </div>
#     <div data-cart-banner-spot="1">
#     </div>
#     <div class="responsive_page_template_content" data-panel='{"autoFocus":true,"navKey":"responsive_page_template_content"}' id="responsive_page_template_content" role="main" style="--store-menu-overlap-height: 46px; --store-menu-floating-height: 46px;">
#      <div data-broadcastuser='{"success":1,"bHideStoreBroadcast":false}' data-config='{"EUNIVERSE":1,"WEB_UNIVERSE":"public","LANGUAGE":"russian","COUNTRY":"RU","MEDIA_CDN_COMMUNITY_URL":"https:\/\/cdn.fastly.steamstatic.com\/steamcommunity\/public\/","MEDIA_CDN_URL":"https:\/\/cdn.fastly.steamstatic.com\/","VIDEO_CDN_URL":"https:\/\/video.fastly.steamstatic.com\/","COMMUNITY_CDN_URL":"https:\/\/community.fastly.steamstatic.com\/","COMMUNITY_CDN_ASSET_URL":"https:\/\/cdn.fastly.steamstatic.com\/steamcommunity\/public\/assets\/","STORE_CDN_URL":"https:\/\/store.fastly.steamstatic.com\/","PUBLIC_SHARED_URL":"https:\/\/store.fastly.steamstatic.com\/public\/shared\/","COMMUNITY_BASE_URL":"https:\/\/steamcommunity.com\/","CHAT_BASE_URL":"https:\/\/steamcommunity.com\/","STORE_BASE_URL":"https:\/\/store.steampowered.com\/","STORE_CHECKOUT_BASE_URL":"https:\/\/checkout.steampowered.com\/","IMG_URL":"https:\/\/store.fastly.steamstatic.com\/public\/images\/","STEAMTV_BASE_URL":"https:\/\/steam.tv\/","HELP_BASE_URL":"https:\/\/help.steampowered.com\/","PARTNER_BASE_URL":"https:\/\/partner.steamgames.com\/","STATS_BASE_URL":"https:\/\/partner.steampowered.com\/","INTERNAL_STATS_BASE_URL":"https:\/\/steamstats.valve.org\/","IN_CLIENT":false,"USE_POPUPS":false,"STORE_ICON_BASE_URL":"https:\/\/shared.fastly.steamstatic.com\/store_item_assets\/steam\/apps\/","STORE_ITEM_BASE_URL":"https:\/\/shared.fastly.steamstatic.com\/store_item_assets\/","WEBAPI_BASE_URL":"https:\/\/api.steampowered.com\/","TOKEN_URL":"https:\/\/store.steampowered.com\/\/chat\/clientjstoken","BUILD_TIMESTAMP":1774996972,"PAGE_TIMESTAMP":1775058226,"IN_TENFOOT":false,"IN_GAMEPADUI":false,"IN_CHROMEOS":false,"IN_MOBILE_WEBVIEW":false,"PLATFORM":"macos","BASE_URL_STORE_CDN_ASSETS":"https:\/\/cdn.fastly.steamstatic.com\/store\/","EREALM":1,"LOGIN_BASE_URL":"https:\/\/login.steampowered.com\/","AVATAR_BASE_URL":"https:\/\/avatars.fastly.steamstatic.com\/","FROM_WEB":true,"WEBSITE_ID":"Store","BASE_URL_SHARED_CDN":"https:\/\/shared.fastly.steamstatic.com\/","CLAN_CDN_ASSET_URL":"https:\/\/clan.fastly.steamstatic.com\/","COMMUNITY_ASSETS_BASE_URL":"https:\/\/shared.fastly.steamstatic.com\/community_assets\/","NOW":1775058226,"SUPPORT_BASE_URL":"https:\/\/steamsupport.valvesoftware.com\/","SNR":"1_5_9_"}' data-hwinfo='{"bSteamOS":false,"bSteamDeck":false}' data-store_page_asset_url='"https:\/\/shared.fastly.steamstatic.com\/store_item_assets\/steam\/apps\/570\/%s?t=1769535998"' data-store_page_extra_assets_map='{"extras\/tournanment_banner.jpg":[{"urlPart":"extras\/45027209f51c38759cea32a32bea6453.avif","extension":"avif","alt_text":null,"urlPartBig":null,"width":"616","height":"192"}],"extras\/english.jpg":[{"urlPart":"extras\/50fe2fd53d58643fa982f7965f446ad7.avif","extension":"avif","alt_text":null,"urlPartBig":null,"width":"618","height":"796"}],"extras\/ign-pca-gamescom2011_small.gif":[{"urlPart":"extras\/4b4823f51bb3893296a2e85c859fbcf4.avif","extension":"avif","alt_text":null,"urlPartBig":null,"width":"186","height":"240"}],"extras\/comic_thumbnail.png":[{"urlPart":"extras\/7e426fc5727aabcd509b1839814a338a.avif","extension":"avif","alt_text":null,"urlPartBig":null,"width":"259","height":"400"}],"extras\/warlock.jpg":[{"urlPart":"extras\/4f9eac31ea575ebffd905409228c0ce6.avif","extension":"avif","alt_text":null,"urlPartBig":null,"width":"570","height":"230"}],"extras\/comic_crop.jpg":[{"urlPart":"extras\/053b0135f3873fca5806c6ff48405689.avif","extension":"avif","alt_text":null,"urlPartBig":null,"width":"570","height":"252"}],"extras\/workshop_dota2workshop.jpg":[{"urlPart":"extras\/66409c187fe8d17c828860a44a84a8ab.avif","extension":"avif","alt_text":null,"urlPartBig":null,"width":"616","height":"202"}],"extras\/workshop_dota2workshop2.jpg":[{"urlPart":"extras\/ebcea62b1a24dff6c7f5a82db9ffb642.avif","extension":"avif","alt_text":null,"urlPartBig":null,"width":"624","height":"202"}],"extras\/signup_button_english.jpg":[{"urlPart":"extras\/71470636fee7e9e64ac9eb82706362f0.avif" ...
#      </div>
#      <div id="application_root">
#       <div class="_2uHYtSBLSS1MxFonkOXr0O">
#        <div class="_2KPA3I9eXE9r251_-GX_iv noOpinionatedGlobalStyles">
#         <div data-accent-color="blue" data-body-text-color="text-light" data-dull-color="greyneutral" style="display: contents;">
#          <div style="display: contents; color: var(--color-text-body-body);">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <script>
#       window.g_wapit="";
#      </script>
#      <link href="https://store.fastly.steamstatic.com/public/css/applications/store/main.css?v=Aoo8HYKehcwb&amp;l=russian&amp;_cdn=fastly" rel="stylesheet" type="text/css"/>
#      <script src="https://store.fastly.steamstatic.com/public/javascript/applications/store/manifest.js?v=3Xv7fvyMV9sg&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#      </script>
#      <script src="https://store.fastly.steamstatic.com/public/javascript/applications/store/libraries~b28b7af69.js?v=VXi50UIeX17k&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#      </script>
#      <script src="https://store.fastly.steamstatic.com/public/javascript/applications/store/main.js?v=WpjmyiyZodKH&amp;l=russian&amp;_cdn=fastly" type="text/javascript">
#      </script>
#      <script type="text/javascript">
#       var g_AccountID = 0;
# 	var g_Languages = ["russian"];
# 	var g_sessionID = "c849a314bdda00ab587a4254";
# 	var g_ServerTime = 1775058226;
# 	var g_bUseNewCartAPI = true;
#
# 			$J( InitMiniprofileHovers( 'https%3A%2F%2Fstore.steampowered.com%2F' ) );
#
#
# 	if ( typeof GStoreItemData != 'undefined' )
# 	{
# 		GStoreItemData.AddNavParams({
# 			__page_default: "1_5_9_",
# 			__page_default_obj: {"domain":"store.steampowered.com","controller":"application","method":"app","submethod":"","feature":null,"depth":null,"countrycode":"RU","webkey":null,"is_client":false,"curator_data":null,"is_likely_bot":false,"is_utm":null},
# 			__originating_obj: {"domain":"store.steampowered.com","controller":"search","method":"search","submethod":"browse","feature":"search-results","depth":1,"countrycode":"RU","webkey":null,"is_client":false,"curator_data":null,"is_likely_bot":false,"is_utm":false},
# 			storemenu_recommendedtags: "1_5_9__17"		});
# 	}
#
# 	if ( typeof GDynamicStore != 'undefined' )
# 	{
# 		GDynamicStore.Init(0, false, "", {"primary_language":null,"secondary_languages":null,"platform_windows":null,"platform_mac":null,"platform_linux":null,"timestamp_updated":null,"hide_store_broadcast":null,"review_score_preference":null,"timestamp_content_descriptor_preferences_updated":null,"provide_deck_feedback":null,"additional_languages":null,"game_frame_rate_reporting":null,"disable_microtrailers":null,"disable_animated_marketing":null}, 'RU',
# 			{"bNoDefaultDescriptors":false});
# 		GStoreItemData.SetCurrencyFormatter(function( nValueInCents, bWholeUnitsOnly ) { var fmt = function( nValueInCents, bWholeUnitsOnly ) {	var format = v_numberformat( nValueInCents / 100, bWholeUnitsOnly ? 0 : 2, ",", "");format = format.replace( ",00", '' ); return format; };var strNegativeSymbol = '';	if ( nValueInCents < 0 ) { strNegativeSymbol = '-'; nValueInCents = -nValueInCents; }return strNegativeSymbol + fmt( nValueInCents, bWholeUnitsOnly ) + " \u0440\u0443\u0431.";});
# 		GStoreItemData.SetCurrencyMinPriceIncrement(1);
# 	}
#      </script>
#      <script type="text/javascript">
#       var g_bUseOldReviewDisplay = false;
#
# 	var g_eDiscoveryQueueType = 0;
#
# 	GStoreItemData.AddStoreItemDataSet(
# 		{"rgApps":{"1282270":{"name":"Strinova","url_name":"Strinova","discount_block":"<div class=\"discount_block  no_discount\" data-price-final=\"0\" data-bundlediscount=\"0\" data-discount=\"0\"><div class=\"discount_prices\"><div class=\"discount_final_price\">\u0411\u0435\u0441\u043f\u043b\u0430\u0442\u043d\u043e<\/div><\/div><\/div>","descids":[],"small_capsulev5":"https:\/\/shared.fastly.steamstatic.com\/store_item_assets\/steam\/apps\/1282270\/43e6108c9a4e84c417f01113b467b5f95f223e70\/capsule_184x69.jpg?t=1773819253","os_windows":true,"has_live_broadcast":false,"localized":true,"localized_english":true},"440":{"name":"Team Fortress 2","url_name":"Team_Fortress_2","discount_block":"<div class=\"discount_block  no_discount\" data-price-final=\"0\" data-bundlediscount=\"0\" data-discount=\"0\"><div class=\"discount_prices\"><div class=\"discount_final_price\">\u0411\u0435\u0441\u043f\u043b\u0430\u0442\u043d\u044b\u0435<\/div><\/div><\/div>","descids":[],"small_capsulev5":"https:\/\/shared.fastly.steamstatic.com\/store_item_assets\/steam\/apps\/440\/capsule_184x69.jpg?t=1757348372","os_windows":true,"os_linux":true,"has_live_broadcast":false,"localized":true,"localized_english":true,"status_string":"Just Updated!"},"2073850":{"name":"THE FINALS","url_name":"THE_FINALS","discount_block":"<div class=\"discount_block  no_discount\" data-price-final=\"322000\" data-bundlediscount=\"0\" data-discount=\"0\"><div class=\"discount_prices\"><div class=\"discount_final_price\">\u0411\u0435\u0441\u043f\u043b\u0430\u0442\u043d\u043e<\/div><\/div><\/div>","descids":[],"small_capsulev5":"https:\/\/shared.fastly.steamstatic.com\/store_item_assets\/steam\/apps\/2073850\/dc50f757c463cc1f7cadbd61a4e63e3ba8d566fa\/capsule_184x69.jpg?t=1774608998","os_windows":true,"has_live_broadcast":false,"localized_english":true},"730":{"name":"Counter-Strike 2","url_name":"CounterStrike_2","discount_block":"<div class=\"discount_block  no_discount\" data-price-final=\"114500\" data-bundlediscount=\"0\" data-discount=\"0\"><div class=\"discount_prices\"><div class=\"discount_final_price\">\u0411\u0435\u0441\u043f\u043b\u0430\u0442\u043d\u044b\u0435<\/div><\/div><\/div>","descids":[2,5],"small_capsulev5":"https:\/\/shared.fastly.steamstatic.com\/store_item_assets\/steam\/apps\/730\/capsule_184x69.jpg?t=1749053861","os_windows":true,"os_linux":true,"has_live_broadcast":false,"localized":true,"localized_english":true,"has_adult_content_violence":true},"761890":{"name":"Albion Online","url_name":"Albion_Online","discount_block":"<div class=\"discount_block  no_discount\" data-price-final=\"0\" data-bundlediscount=\"0\" data-discount=\"0\"><div class=\"discount_prices\"><div class=\"discount_final_price\">\u0411\u0435\u0441\u043f\u043b\u0430\u0442\u043d\u044b\u0435<\/div><\/div><\/div>","descids":[],"small_capsulev5":"https:\/\/shared.fastly.steamstatic.com\/store_item_assets\/steam\/apps\/761890\/1306c035b47b8734e8b0bf264c2138b28461f097\/capsule_184x69.jpg?t=1771498723","os_windows":true,"os_macos":true,"os_linux":true,"has_live_broadcast":false,"localized":true,"localized_english":true},"2943650":{"name":"FragPunk","url_name":"FragPunk","discount_block":"<div class=\"discount_block  no_discount\" data-price-final=\"0\" data-bundlediscount=\"0\" data-discount=\"0\"><div class=\"discount_prices\"><div class=\"discount_final_price\">\u0411\u0435\u0441\u043f\u043b\u0430\u0442\u043d\u043e<\/div><\/div><\/div>","descids":[],"small_capsulev5":"https:\/\/shared.fastly.steamstatic.com\/store_item_assets\/steam\/apps\/2943650\/fba2d3346dc2f27182ab7e5b750cdb1eddc39374\/capsule_184x69.jpg?t=1769680898","os_windows":true,"has_live_broadcast":false,"localized":true,"localized_english":true},"3889960":{"name":"Warface","url_name":"Warface","discount_block":"<div class=\"discount_block  no_discount\" data-price-final=\"0\" data-bundlediscount=\"0\" data-discount=\"0\"><div class=\"discount_prices\"><div class=\"discount_final_price\">\u0411\u0435\u0441\u043f\u043b\u0430\u0442\u ...
# 	GStoreItemData.AddNavParams( {
# 		recommended: "1_5_9__300",
# 		recommend_franchise: "1_5_9__316",
# 		more_from_franchise: "1_5_9__317",
# 		bundle_component_preview: "1_5_9__412",
# 		recommended_ranked_played: "1_5_9__862",
# 	} );
#
# 	$J( function() {
# 		var $Expander = $J('#devnotes_expander');
# 		if( $Expander.length && $Expander.height() < parseInt( $Expander.css('max-height') ) ) {
# 			$J('#devnotes_more').hide();
# 		}
#
# 		CollapseLongStrings( '.dev_row .summary.column' );
#
# 				InitAutocollapse();
# 		InitHorizontalAutoSliders();
#
# 		Responsive_ReparentItemsInResponsiveMode( '.responsive_apppage_details_right', $J('#responsive_apppage_details_right_ctn') );
# 		Responsive_ReparentItemsInResponsiveMode( '.responsive_apppage_details_left', $J('#responsive_apppage_details_left_ctn') );
# 		Responsive_ReparentItemsInResponsiveMode( '.responsive_apppage_reviewblock', $J('#responsive_apppage_reviewblock_ctn') );
#
# 		//hack to workaround chrome bug
# 		$J('#responsive_apppage_reviewblock_ctn' ).css('width', '100%' );
# 		window.setTimeout( function() { $J('#responsive_apppage_reviewblock_ctn').css('width', '' ); }, 1 );
#
# 				var watcher = new CScrollOffsetWatcher( $J('#app_reviews_hash'), OnLoadReviews );
# 		watcher.SetBufferHeight( 0 );
#
# 				InitPlaytimeFilterSlider();
#
# 		// on Tablet wait to do this when the window is fully loaded - see OnPageLoaded()
# 				ReparentAppLandingPageForSmallScreens();
#
#
# 				AddRightNavStickyPaddingOnTablet();
#
# 			var usability = InitUsabilityTracker( "https:\/\/store.steampowered.com\/app\/usabilitytracking\/570" );
# 		usability.ScheduleUpload();
#
#
# 		SetupReviewFilterMenus();
#
# 			} );
#
#
# 	function OpenTagModal()
# 	{
# 		ShowAppTagModal( 570 );
# 	}
#      </script>
#      <div class="game_page_background game" data-miniprofile-appid="570">
#       <div class="banner_open_in_steam">
#        <div data-featuretarget="open-in-desktop-client">
#         <div class="_1EQpm6hAsghyCST7W04m-E">
#          <div class="_13oFTFTjvz0YaOVnWZxyqr">
#           <div class="_1lwkSayKFi-9WCDd6pq5bV">
#            <div class="_1jso7z80FWGn42k1HP0_cf">
#             Открыть в настольном приложении
#            </div>
#           </div>
#           <div class="_1HSa8QK0U-qQCGObG6XYFT">
#            <div class="_3Xfc_DOo4BUZBmxkSRmD6y">
#             <b>
#              Вы не вошли в аккаунт!
#             </b>
#             <br/>
#             Откройте эту страницу в приложении Steam, чтобы купить продукт, добавить его в желаемое, подписаться на него и увидеть рекомендации
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <!-- create two column layout for Deck, Tablet sized screens -->
#       <div class="tablet_grid" id="tabletGrid">
#        <div class="page_content_ctn" itemscope="" itemtype="http://schema.org/Product">
# ...
#              </div>
#              <div class="active_filter" id="reviews_filter_purchase_type" onclick="ClearReviewPurchaseTypeFilter()" role="button">
#              </div>
#              <div class="active_filter" id="reviews_filter_language" onclick="ClearReviewLanguageFilter()" role="button">
#              </div>
#              <div class="active_filter" id="reviews_filter_graph" onclick="ClearReviewDateRangeFilter()" role="button">
#               <span id="review_selected_histogram_date_range_prefix">
#               </span>
#               <span id="review_selected_histogram_date_range_text">
#               </span>
#              </div>
#              <div class="active_filter" id="reviews_filter_offtopic_activity" onclick="ClearOfftopicReviewActivityFilter()" role="button">
#               Исключать обзоры не по теме
#              </div>
#              <div class="active_filter" id="reviews_filter_playtime" onclick="ClearReviewPlaytimeFilter()" role="button">
#               Время в игре:
#               <span id="review_playtime_preset_text">
#               </span>
#              </div>
#              <div class="active_filter" id="reviews_filter_deck_playtime" onclick="ClearDeckPlaytimeFilter()" role="button">
#               В основном на Steam Deck
#              </div>
#              <div class="active_filter" id="reviews_filter_hardware_os" onclick="ClearHardwareFilter( 'hardware_os' )" role="button">
#               Операционная система:
#               <span>
#               </span>
#              </div>
#              <div class="active_filter" id="reviews_filter_hardware_cpu_name" onclick="ClearHardwareFilter( 'hardware_cpu_name' )" role="button">
#               CPU:
#               <span>
#               </span>
#              </div>
#              <div class="active_filter" id="reviews_filter_hardware_gfx_adapter_description" onclick="ClearHardwareFilter( 'hardware_gfx_adapter_description' )" role="button">
#               GPU:
#               <span>
#               </span>
#              </div>
#              <div class="active_filter" id="reviews_filter_hardware_gaming_device_type" onclick="ClearHardwareFilter( 'hardware_gaming_device_type' )" role="button">
#               Тип устройства:
#               <span>
#               </span>
#              </div>
#             </div>
#             <div class="user_reviews_filter_score visible" id="user_reviews_filter_score">
#             </div>
#             <a class="user_reviews_summary_row" href="#app_reviews_hash" id="appReviewsAll_Detail" style="display: none;">
#              <div class="subtitle column all">
#               Все обзоры:
#              </div>
#              <div class="summary column">
#               <span class="responsive_reviewdesc_short">
#                <span class="desc_short">
#                 Обзоры (русский язык)
#                </span>
#                <span class="game_review_summary positive">
#                 В основном положительные
#                </span>
#                (75% из 1,326,925)
#               </span>
#              </div>
#             </a>
#             <a class="user_reviews_summary_row" data-tooltip-html="65% из 20,212 обзоров пользователей за последние 30 дней положительные." href="#app_reviews_hash" id="appReviewsRecent_Detail" style="display: none;">
#              <div class="subtitle column">
#               Недавние обзоры:
#              </div>
#              <div class="summary column">
#               <span class="responsive_reviewdesc_short">
#                <span class="desc_short">
#                 Недавно:
#                </span>
#                <span class="game_review_summary mixed">
#                 Смешанные
#                </span>
#                (65% из 20,212)
#               </span>
#              </div>
#             </a>
#            </div>
#            <div id="review_selected_filters">
#            </div>
#            <div data-featuretarget="appreviews" data-props='{"appid":570,"app_release_date":"1373389200","appname":"Dota 2","summary_num_positive_reviews":1002991,"summary_num_reviews":1326925}'>
#             <div>
#              <div class="_2-8QGxhaDbQ3lfs-nUqFJZ">
#              </div>
#             </div>
#            </div>
#            <div style="clear: left">
#            </div>
#           </div>
#          </div>
#         </div>
#         <div id="reviewSettingsPopupCtn" style="display: none;">
#          <div class="review_settings_popup_content" id="reviewSettingsPopupContent">
#           <div class="review_settings_popup_header">
#            <div>
#             Фильтры обзоров
#            </div>
#            <div onclick="CloseReviewSettingsModal();">
#             <img src="https://store.fastly.steamstatic.com/public/images/v6/close_btn.png"/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="purchase_options_content_tablet" data-panel='{"maintainY":true,"bFocusRingRoot":true,"onMoveDown":"BlockMovement","flow-children":"column"}' id="purchaseOptionsContentTablet" style="display: none;">
#         <!-- game_area_purchase goes here -->
#        </div>
#       </div>
#      </div>
#      <div class="hover game_hover" id="global_hover" style="display: none; left: 0; top: 0;">
#       <div class="game_hover_box hover_box">
#        <div class="content" id="global_hover_content">
#        </div>
#       </div>
#       <div class="hover_arrow_left">
#       </div>
#       <div class="hover_arrow_right">
#       </div>
#      </div>
#      <div id="EmbedModal" style="display: none">
#       <div id="widget_create">
#        <p>
#         Вы можете использовать этот инструмент для создания виджета, чтобы сгенерировать HTML-код и вставить его в ваш веб-сайт, чтобы покупатели могли без труда приобрести игру в Steam.
#        </p>
#        <p class="small">
#         Введите описание к вашему виджету длиной до 375 символов:
#        </p>
#        <div class="app_embed_dialog_description">
#         <textarea maxlength="375" name="w_text" placeholder="Ежедневно миллионы игроков по всему миру сражаются от лица одного из более сотни героев Dota 2, и даже после тысячи часов в ней есть чему научиться. Благодаря регулярным обновлениям игра живёт своей жизнью: геймплей, возможности и герои постоянно преображаются."></textarea>
#        </div>
#        <div class="buttoncontainer">
#         <a class="btnv6_blue_hoverfade btn_medium" href="#" onclick="CreateWidget(570); return false;">
#          <span>
#           Создать виджет
#          </span>
#         </a>
#        </div>
#       </div>
#       <div id="widget_finished" style="display: none;">
#        <div id="widget_container">
#        </div>
#        <p class="small">
#         Скопируйте HTML-код ниже на ваш сайт, чтобы там появился такой же виджет
#        </p>
#        <textarea id="widget_code" style=""></textarea>
#       </div>
#      </div>
#      <div class="app_tag_modal nologin" id="app_tagging_modal" style="display: none;">
#       <div class="app_tag_modal_content">
#        <div class="app_tag_modal_seperator">
#        </div>
#        <div class="app_tag_modal_left">
#         <h2>
#          Популярные метки для этого продукта:
#          <span class="app_tag_modal_tooltip" data-tooltip-text="Это метки, добавленные к продукту большинством пользователей. Вы можете щелкнуть по метке, чтобы найти продукты с такой же меткой. Кроме того, вы можете нажать значок «+» рядом с любой добавленной меткой, чтобы повысить ее популярность на странице этого продукта.">
#           (?)
#          </span>
#         </h2>
#         <div class="app_tags popular_tags">
#         </div>
#        </div>
#        <div class="app_tag_modal_right">
#         <h2>
#          Войти
#         </h2>
#         <p>
#          Войдите, чтобы добавить собственные метки для этого продукта.
#         </p>
#         <p>
#          <a class="btnv6_blue_hoverfade btn_medium" href="https://store.steampowered.com/login/?redir=app/570">
#           <span>
#            Войти
#           </span>
#          </a>
#         </p>
#        </div>
#        <div style="clear: both;">
#        </div>
#       </div>
#      </div>
#      <script type="text/javascript">
#       $J( function() {
# 			InitAppTagModal( 570,
# 				[{"tagid":113,"name":"\u0411\u0435\u0441\u043f\u043b\u0430\u0442\u043d\u0430\u044f \u0438\u0433\u0440\u0430","count":60338,"browseable":true},{"tagid":1718,"name":"MOBA","count":20411,"browseable":true},{"tagid":3859,"name":"\u0414\u043b\u044f \u043d\u0435\u0441\u043a\u043e\u043b\u044c\u043a\u0438\u0445 \u0438\u0433\u0440\u043e\u043a\u043e\u0432","count":15583,"browseable":true},{"tagid":9,"name":"\u0421\u0442\u0440\u0430\u0442\u0435\u0433\u0438\u044f","count":14447,"browseable":true},{"tagid":5055,"name":"\u041a\u0438\u0431\u0435\u0440\u0441\u043f\u043e\u0440\u0442","count":11964,"browseable":true},{"tagid":5711,"name":"\u041a\u043e\u043c\u0430\u043d\u0434\u043d\u0430\u044f","count":11092,"browseable":true},{"tagid":3878,"name":"\u0421\u043e\u0440\u0435\u0432\u043d\u043e\u0432\u0430\u0442\u0435\u043b\u044c\u043d\u0430\u044f","count":8432,"browseable":true},{"tagid":19,"name":"\u042d\u043a\u0448\u0435\u043d","count":8014,"browseable":true},{"tagid":3843,"name":"\u0421\u0435\u0442\u0435\u0432\u043e\u0439 \u043a\u043e\u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432","count":7576,"browseable":true},{"tagid":1775,"name":"\u0418\u0433\u0440\u043e\u043a \u043f\u0440\u043e\u0442\u0438\u0432 \u0438\u0433\u0440\u043e\u043a\u0430","count":6164,"browseable":true},{"tagid":4026,"name":"\u0421\u043b\u043e\u0436\u043d\u0430\u044f","count":5473,"browseable":true},{"tagid":1685,"name":"\u041a\u043e\u043e\u043f\u0435\u0440\u0430\u0442\u0438\u0432","count":4401,"browseable":true},{"tagid":1676,"name":"\u0421\u0442\u0440\u0430\u0442\u0435\u0433\u0438\u044f \u0432 \u0440\u0435\u0430\u043b\u044c\u043d\u043e\u043c \u0432\u0440\u0435\u043c\u0435\u043d\u0438","count":4179,"browseable":true},{"tagid":1645,"name":"\u0411\u0430\u0448\u0435\u043d\u043d\u0430\u044f \u0437\u0430\u0449\u0438\u0442\u0430","count":3867,"browseable":true},{"tagid":122,"name":"\u0420\u043e\u043b\u0435\u0432\u0430\u044f \u0438\u0433\u0440\u0430","count":3864,"browseable":true},{"tagid":1684,"name":"\u0424\u044d\u043d\u0442\u0435\u0437\u0438","count":3824,"browseable":true},{"tagid":4747,"name":"\u041a\u0430\u0441\u0442\u043e\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u043f\u0435\u0440\u0441\u043e\u043d\u0430\u0436\u0430","count":3001,"browseable":true},{"tagid":4711,"name":"\u0420\u0435\u0438\u0433\u0440\u0430\u0431\u0435\u043b\u044c\u043d\u043e\u0441\u0442\u044c","count":2799,"browseable":true},{"tagid":4231,"name":"\u0420\u043e\u043b\u0435\u0432\u043e\u0439 \u044d\u043a\u0448\u0435\u043d","count":2500,"browseable":true},{"tagid":599,"name":"\u0421\u0438\u043c\u0443\u043b\u044f\u0442\u043e\u0440","count":2018,"browseable":true}],
# 				[],
# 				"1_5_9__410",
# 				"1_5_9__411",
# 				null,
# 				false			);
#
# 						if ( typeof GDynamicStore != 'undefined' )
# 				GDynamicStore.FixupNamePortion();
#
# 					});
#      </script>
#     </div>
#     <!-- responsive_page_legacy_content -->
#     <div class="" id="footer_spacer" style="">
#     </div>
#     <div class="" id="footer" role="contentinfo">
#      <div class="footer_content">
#       <div class="rule">
#       </div>
#       <div id="footer_logo_steam">
#        <img alt="Valve Software" border="0" src="https://store.fastly.steamstatic.com/public/images/v6/logo_steam_footer.png"/>
#       </div>
#       <div id="footer_logo">
#        <a href="http://www.valvesoftware.com" rel="" target="_blank">
#         <img alt="Valve Software" border="0" src="https://store.fastly.steamstatic.com/public/images/footerLogo_valve_new.png"/>
#        </a>
#       </div>
#       <div data-panel='{"flow-children":"row"}' id="footer_text">
#        <div>
#         © 2026 Valve Corporation. Все права сохранены. Все торговые марки являются собственностью соответствующих владельцев в США и других странах.
#        </div>
#        <div>
#         НДС включён во все цены, где он применим.
#         <a href="https://store.steampowered.com/privacy_agreement/?snr=1_44_44_" rel="" target="_blank">
#          Политика конфиденциальности
#         </a>
#         <span aria-hidden="true">
#          |
#         </span>
#         <a href="https://store.steampowered.com/legal/?snr=1_44_44_" rel="" target="_blank">
#          Правовая информация
#         </a>
#         <span aria-hidden="true">
#          |
#         </span>
#         <a href="https://help.steampowered.com/faqs/view/10BB-D27A-6378-4436?snr=1_44_44_" rel="" target="_blank">
#          Доступность
#         </a>
#         <span aria-hidden="true">
#          |
#         </span>
#         <a href="https://store.steampowered.com/subscriber_agreement/?snr=1_44_44_" rel="" target="_blank">
#          Соглашение подписчика Steam
#         </a>
#         <span aria-hidden="true">
#          |
#         </span>
#         <a href="https://store.steampowered.com/steam_refunds/?snr=1_44_44_" rel="" target="_blank">
#          Возвраты
#         </a>
#         <span aria-hidden="true">
#          |
#         </span>
#         <a href="https://store.steampowered.com/account/cookiepreferences/?snr=1_44_44_" rel="" target="_blank">
#          Файлы cookie
#         </a>
#        </div>
#        <div class="responsive_optin_link">
#         <div class="btn_medium btnv6_grey_black" onclick="Responsive_RequestMobileView()" role="link">
#          <span>
#           Мобильная версия
#          </span>
#         </div>
#        </div>
#       </div>
#       <div style="clear: left;">
#       </div>
#       <br/>
#       <div class="rule">
#       </div>
#       <div class="valve_links" data-panel='{"flow-children":"row"}'>
#        <a href="http://www.valvesoftware.com/about" rel="" target="_blank">
#         О Valve
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="http://www.valvesoftware.com" rel="" target="_blank">
#         Вакансии
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="http://www.steampowered.com/steamworks/" rel="" target="_blank">
#         Steamworks
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="https://partner.steamgames.com/steamdirect" rel="" target="_blank">
#         Дистрибуция Steam
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="https://help.steampowered.com/ru/?snr=1_44_44_">
#         Служба поддержки
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="https://store.steampowered.com/digitalgiftcards/?snr=1_44_44_" rel="" target="_blank">
#         Подарочные карты
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="https://steamcommunity.com/linkfilter/?u=http%3A%2F%2Fwww.facebook.com%2FSteam" rel="noopener" target="_blank">
#         <img alt="Facebook: Steam" src="https://store.fastly.steamstatic.com/public/images/ico/ico_facebook.png"/>
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="http://twitter.com/steam" rel="" target="_blank">
#         <img alt="X: @Steam" src="https://store.fastly.steamstatic.com/public/images/ico/ico_twitter.png"/>
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="https://steamcommunity.com/linkfilter/?u=https%3A%2F%2Fbsky.app%2Fprofile%2Fsteampowered.com" rel="noopener" target="_blank">
#         <img alt="Bluesky: Steampowered" src="https://store.fastly.steamstatic.com/public/images/ico/ico_bsky.png"/>
#        </a>
#       </div>
#       <div class="extra_space">
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- responsive_page_content -->
#   </div>
#   <div class="miniprofile_hover" style="display: none;">
#    <div class="shadow_ul">
#    </div>
#    <div class="shadow_top">
#    </div>
#    <div class="shadow_ur">
#    </div>
#    <div class="shadow_left">
#    </div>
#    <div class="shadow_right">
#    </div>
#    <div class="shadow_bl">
#    </div>
#    <div class="shadow_bottom">
#    </div>
#    <div class="shadow_br">
#    </div>
#    <div class="miniprofile_hover_inner shadow_content">
#    </div>
#   </div>
#   <!-- responsive_page_frame -->
#   <div class="FullModalOverlay" style="display: none;">
#    <div class="ModalOverlayContent ModalOverlayBackground">
#    </div>
#   </div>
#  </body>
# </html>
