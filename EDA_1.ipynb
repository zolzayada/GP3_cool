# %%
import pandas as pd

# %%
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', 60)

# %%
steam = pd.read_csv('games5.csv')
api = pd.read_csv('api_FINAL_FINAL.csv')

# %% [markdown]
# После считывания файлов, переназовем колонки, чтобы у всех были соответсвующие названия

# %%
steam.columns = [
    'link',
    'name',
    'release_date',
    'developers',
    'genre',
    'price',
    'discount',
    'dlc',
    'tags',
    'rating_steam',
    'reviews_count',
    'recent_rating',
    'recent_reviews_count'
]

# %% [markdown]
# Объединим датасеты по названию игры:

# %%
df = steam.merge(api, on='name', how='inner')
df.head()
# Out:
#                                                 link              name  \
# 0  https://store.steampowered.com/app/730/Counter...  Counter-Strike 2
# 1  https://store.steampowered.com/app/3321460/Cri...    Crimson Desert
# 2  https://store.steampowered.com/app/2868840/Sla...  Slay the Spire 2
# 3  https://store.steampowered.com/app/2050650/Res...   Resident Evil 4
# 4  https://store.steampowered.com/app/1172470/Ape...     Apex Legends™
#
#   release_date        developers                                    genre  \
# 0   2012-08-21             Valve               ['Action', 'Free To Play']
# 1          NaN       Pearl Abyss       ['Экшены', 'Приключенческие игры']
# 2   2026-03-05         Mega Crit    ['Indie', 'Strategy', 'Early Access']
# 3   2023-03-24  CAPCOM Co., Ltd.                  ['Action', 'Adventure']
# 4   2020-11-04           Respawn  ['Action', 'Adventure', 'Free To Play']
#
#           price discount   dlc  \
# 0  Free To Play       0%   1.0
# 1        69,99€       0%   1.0
# 2        22,99€       0%   0.0
# 3       100,24€     -60%  27.0
# 4  Free To Play       0%   0.0
#
#                                                 tags             rating_steam  \
# 0  ['FPS', 'Shooter', 'Multiplayer', 'Competitive...            Very Positive
# 1  ['Открытый мир', 'Экшен', 'Для одного игрока',...      Очень положительные
# 2  ['Strategy', 'Roguelike', 'Card Game', 'Deckbu...            Very Positive
# 3  ['Horror', 'Action', 'Survival Horror', 'Third...  Overwhelmingly Positive
# 4  ['Free to Play', 'Battle Royale', 'Multiplayer...                    Mixed
#
#   reviews_count_x            recent_rating recent_reviews_count  rating  \
# 0       9,521,157          Mostly Positive               94,756    3.57
# 1          78 700                      NaN                  NaN    3.68
# 2          98,132          Mostly Positive               85,557    0.00
# 3         157,050  Overwhelmingly Positive                7,371    4.58
# 4       1,040,934                    Mixed                8,265    3.63
#
#    reviews_count_y  playtime  \
# 0            216.0       0.0
# 1             19.0       0.0
# 2              5.0       7.0
# 3            635.0      24.0
# 4           2439.0       5.0
#
#                                            platforms  \
# 0                                    ['PC', 'Linux']
# 1  ['PC', 'PlayStation 5', 'Xbox One', 'PlayStati...
# 2                           ['PC', 'macOS', 'Linux']
# 3  ['PC', 'PlayStation 5', 'PlayStation 4', 'Xbox...
# 4  ['PC', 'Xbox One', 'PlayStation 4', 'Nintendo ...
#
#                                               stores   esrb_rating  id_games  \
# 0                                          ['Steam']        Mature    965470
# 1                                                NaN           NaN    529829
# 2                                          ['Steam']  Everyone 10+    994601
# 3                     ['Steam', 'PlayStation Store']        Mature    795632
# 4  ['Steam', 'PlayStation Store', 'Xbox Store', '...          Teen    290856
#
#    metacritic  achievements_count  a_count  series_count  dev_team_count
# 0         NaN                 0.0      0.0           0.0             1.0
# 1         NaN                 0.0      0.0           0.0             0.0
# 2         NaN                 0.0      0.0           1.0             1.0
# 3         NaN                34.0      0.0          28.0             7.0
# 4        80.0                12.0     21.0           1.0             3.0

# %% [markdown]
# Узнаем основные данные по получившемуся датафрейму:

# %%
print("Размеры датасета: ", df.shape)
print("Колонки датасета: ", df.columns)
# Out:
# Размеры датасета:  (9672, 25)
# Колонки датасета:  Index(['link', 'name', 'release_date', 'developers', 'genre', 'price',
#        'discount', 'dlc', 'tags', 'rating_steam', 'reviews_count_x',
#        'recent_rating', 'recent_reviews_count', 'rating', 'reviews_count_y',
#        'playtime', 'platforms', 'stores', 'esrb_rating', 'id_games',
#        'metacritic', 'achievements_count', 'a_count', 'series_count',
#        'dev_team_count'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9672 entries, 0 to 9671
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   link                  9672 non-null   object
#  1   name                  9671 non-null   object
#  2   release_date          9665 non-null   object
#  3   developers            9668 non-null   object
#  4   genre                 9672 non-null   object
#  5   price                 9632 non-null   object
#  6   discount              9556 non-null   object
#  7   dlc                   9670 non-null   float64
#  8   tags                  9672 non-null   object
#  9   rating_steam          3734 non-null   object
#  10  reviews_count_x       3734 non-null   object
#  11  recent_rating         3569 non-null   object
#  12  recent_reviews_count  3569 non-null   object
#  13  rating                9672 non-null   float64
#  14  reviews_count_y       9672 non-null   float64
#  15  playtime              9672 non-null   float64
#  16  platforms             9638 non-null   object
#  17  stores                9230 non-null   object
#  18  esrb_rating           2849 non-null   object
#  19  id_games              9672 non-null   int64
#  20  metacritic            2582 non-null   float64
#  21  achievements_count    9672 non-null   float64
#  22  a_count               8516 non-null   float64
#  23  series_count          9621 non-null   float64
#  24  dev_team_count        9669 non-null   float64
# dtypes: float64(9), int64(1), object(15)
# memory usage: 1.8+ MB
